# %% [markdown]
# # Task 2

# %% [markdown]
# Task: City Analysis
#
# Identify the city with the highest number of restaurants in the dataset.

# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("C:\\Users\\abhis\\Downloads\\Dataset .csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
print(df.shape)
# Out:
# (9551, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.groupby(by='City')[['Restaurant Name']].sum()
# Out:
#                                                    Restaurant Name
# City
# Abu Dhabi        Denny'sFamous Dave's BarbecuePizza Di RoccoSof...
# Agra             JahanpanahRangrezz RestaurantTime2Eat - Mama C...
# Ahmedabad        650 - The Global KitchenPatang - The Revolving...
# Albany           Austin's BBQ and Oyster BarBJ's Country Buffet...
# Allahabad        Aryan Family's DelightBean HereBikanerwalaDews...
# ...                                                            ...
# Weirton                   Theo Yianni's Authentic Greek Restaurant
# Wellington City  Maranui CafeFive BoroughsEkim BurgersOmbraThe ...
# Winchester Bay                           Fishpatrick's Crabby Cafe
# Yorkton                                              Arigato Sushi
# ��stanbul        J'adore ChocolatierStarbucksValoniaDraft Gastr...
#
# [140 rows x 1 columns]

# %%
city_rest=df.groupby(by='City')[['Restaurant Name']].value_counts()

# %%
city_rest.sort_values(ascending=False)
# Out:
# City       Restaurant Name
# New Delhi  Cafe Coffee Day             57
#            Domino's Pizza              55
#            Subway                      38
#            Green Chick Chop            37
#            McDonald's                  33
#                                        ..
#            Sugar Boutique               1
#            Sugar Loft                   1
#            Sugar Rush                   1
#            Sugarama Patisserie          1
# ��stanbul  Walter's Coffee Roastery     1
# Length: 7965, dtype: int64

# %% [markdown]
# ## New Delhi have the highest number of restaurants.

# %% [markdown]
# # Calculate the average rating for restaurants in each city.

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
city_rest_rating=df.groupby(by='City')[['Restaurant Name','Aggregate rating']].value_counts()

# %%
city_rest_rating
# Out:
# City       Restaurant Name           Aggregate rating
# Abu Dhabi  Applebee's                4.0                 1
#            Via Delhi                 4.0                 1
#            Tikka Tonight             4.0                 1
#            The Cheesecake Factory    4.6                 1
#            Tamba                     4.7                 1
#                                                         ..
# ��stanbul  Leman K�_lt�_r            3.7                 1
#            Naml۱ Gurme               4.1                 1
#            Starbucks                 4.9                 1
#            Valonia                   4.2                 1
#            Walter's Coffee Roastery  4.0                 1
# Length: 9002, dtype: int64

# %%
city_rest_rating=df.groupby(by='City')[['Restaurant Name','Aggregate rating']].mean()
city_rest_rating
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_12360\2222579058.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city_rest_rating=df.groupby(by='City')[['Restaurant Name','Aggregate rating']].mean()
#                  Aggregate rating
# City
# Abu Dhabi                4.300000
# Agra                     3.965000
# Ahmedabad                4.161905
# Albany                   3.552941
# Allahabad                3.395000
# ...                           ...
# Weirton                  3.900000
# Wellington City          4.250000
# Winchester Bay           3.200000
# Yorkton                  3.300000
# ��stanbul                4.292857
#
# [140 rows x 1 columns]

# %%
city_rest_rating.head(1)
# Out:
#            Aggregate rating
# City
# Abu Dhabi               4.3

# %% [markdown]
# Abu Dhabi is the city which have highest average rating.
